# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import googlemaps
from sake_dashboard import creds
import plotly.graph_objects as go
import plotly.express as px
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [189], in <cell line: 6>()
#       4 from bs4 import BeautifulSoup as bs
#       5 import googlemaps
# ----> 6 from sake_dashboard import creds
#       7 import plotly.graph_objects as go
#       8 import plotly.express as px
#
# ModuleNotFoundError: No module named 'sake_dashboard'

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns= 100

# %%
df_sake = pd.read_csv('../data/sake_list.csv').drop(columns=["Unnamed: 0", "Unnamed: 0.1"])

# %%
df_sake.tail(3)
# Out:
#                      name                      name_kana  \
# 14803    無濾過原酒 年魚市 初しぼり生酒          むろかげんしゅ あゆち はつしぼりなまざけ
# 14804      無濾過原酒 年魚市 純米吟醸         むろかげんしゅ あゆち じゅんまいぎんじょう
# 14805  月読みの宴 ひやおろし 純米吟醸原酒  つくよみのうたげ ひやおろし じゅんまいぎんじょうげんしゅ
#
#                                           name_romaji sake_type rice_type  \
# 14803        MurokaGenshu Ayuchi HatsushiboriNamazake     純米吟醸酒       夢山水
# 14804                MurokaGenshu Ayuchi Junmaiginjou     純米吟醸酒       夢山水
# 14805  TsukuyominoUtage Hiyaoroshi JunmaiginjouGenshu     純米吟醸酒       夢山水
#
#       rice_origin yeast rice_polishing_rate   abv acidity amino gravity  \
# 14803         愛知県     -                  60  17.5    1.90  1.40     2.0
# 14804         愛知県     -                  60  17.5    1.90  1.40     2.0
# 14805         愛知県     -                  60  17.5    1.90  1.40     2.0
#
#              volume prefecture city company                  address  \
# 14803  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14804  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14805  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
#
#                          website     brand
# 14803  https://www.sonnoh.co.jp/  年魚市(あゆち)
# 14804  https://www.sonnoh.co.jp/  年魚市(あゆち)
# 14805  https://www.sonnoh.co.jp/  尊皇(そんのう)

# %% [markdown]
# ## stakeholders and project value

# %% [markdown]
# stakeholders
# - me - my own interest
# - foreigners - want to learn more about sake in English
# - sake sommeliers / experts - want to explore sake data
# - sake brewers - want to know where sake is being brewed
#
# what I'm interested in learning from the data
# - which prefectures have many breweries / sake?
# - where is a higher rate of high / low quality sake produced?
# - are there defining features of sake for different prefectures (eg sake type, abv, acidity, etc)?  If so, what are they?  What features aren't unique?
# - what climate and geographic factors play in brewery / sake production density?

# %% [markdown]
# ## data cleaning

# %%
def clean_df(df_sake):
    # replace "-" with NAs
    df_sake = df_sake.replace("-", np.nan)

    # clean yeast strings
    df_sake['yeast'] = df_sake.yeast.replace(to_replace="[  *\n\r]", value="", regex=True)

    # change rice polishing rate from string to float
    df_sake['rice_polishing_rate'] = df_sake.rice_polishing_rate.astype('float')

    # clean and create high, low, and avg columns for abv, acidity, amino, and gravity, all as floats
    df_sake['abv_low'] = df_sake.abv.str.split("~").str[0].astype('float')
    df_sake['abv_high'] = df_sake.abv.str.split("~").str[-1].astype('float')
    df_sake['abv_avg'] = df_sake[['abv_low', 'abv_high']].mean(axis=1)

    df_sake['acidity'] = df_sake.acidity.replace(to_replace="[  *\n\r]", value="", regex=True)
    df_sake['acidity_low'] = df_sake.acidity.str.split("~").str[0].astype('float')
    df_sake['acidity_high'] = df_sake.acidity.str.split("~").str[-1].astype('float')
    df_sake['acidity_avg'] = df_sake[['acidity_low', 'acidity_high']].mean(axis=1)

    df_sake['amino'] = df_sake.amino.replace(to_replace="[  *\n\r]", value="", regex=True)
    df_sake['amino_low'] = df_sake.amino.str.split("~").str[0].astype('float')
    df_sake['amino_high'] = df_sake.amino.str.split("~").str[-1].astype('float')
    df_sake['amino_avg'] = df_sake[['amino_low', 'amino_high']].mean(axis=1)

    df_sake['gravity'] = df_sake.gravity.replace(to_replace="[  *\n\r]", value="", regex=True)
    df_sake['gravity_low'] = df_sake.gravity.str.split("~").str[0].astype('float')
    df_sake['gravity_high'] = df_sake.gravity.str.split("~").str[-1].astype('float')
    df_sake['gravity_avg'] = df_sake[['gravity_low', 'gravity_high']].mean(axis=1)
    
    return df_sake

# %%
df_sake = clean_df(df_sake)
df_sake.tail(3)
# Out:
#                      name                      name_kana  \
# 14803    無濾過原酒 年魚市 初しぼり生酒          むろかげんしゅ あゆち はつしぼりなまざけ
# 14804      無濾過原酒 年魚市 純米吟醸         むろかげんしゅ あゆち じゅんまいぎんじょう
# 14805  月読みの宴 ひやおろし 純米吟醸原酒  つくよみのうたげ ひやおろし じゅんまいぎんじょうげんしゅ
#
#                                           name_romaji sake_type rice_type  \
# 14803        MurokaGenshu Ayuchi HatsushiboriNamazake     純米吟醸酒       夢山水
# 14804                MurokaGenshu Ayuchi Junmaiginjou     純米吟醸酒       夢山水
# 14805  TsukuyominoUtage Hiyaoroshi JunmaiginjouGenshu     純米吟醸酒       夢山水
#
#       rice_origin yeast  rice_polishing_rate   abv acidity amino gravity  \
# 14803         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
# 14804         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
# 14805         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
#
#              volume prefecture city company                  address  \
# 14803  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14804  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14805  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
#
#                          website     brand  abv_low  abv_high  abv_avg  \
# 14803  https://www.sonnoh.co.jp/  年魚市(あゆち)     17.5      17.5     17.5
# 14804  https://www.sonnoh.co.jp/  年魚市(あゆち)     17.5      17.5     17.5
# 14805  https://www.sonnoh.co.jp/  尊皇(そんのう)     17.5      17.5     17.5
#
#        acidity_low  acidity_high  acidity_avg  amino_low  amino_high  \
# 14803          1.9           1.9          1.9        1.4         1.4
# 14804          1.9           1.9          1.9        1.4         1.4
# 14805          1.9           1.9          1.9        1.4         1.4
#
#        amino_avg  gravity_low  gravity_high  gravity_avg
# 14803        1.4          2.0           2.0          2.0
# 14804        1.4          2.0           2.0          2.0
# 14805        1.4          2.0           2.0          2.0

# %% [markdown]
# ## missingness

# %% [markdown]
# ### missing company and location

# %%
df_sake[df_sake['company'].isna()]
# Out:
#                 name                      name_kana  \
# 2541  特別本醸造 生貯蔵酒 副将軍  とくべつほんじょうぞう なまちょぞうしゅ  ふくしょうぐん
# 3003        燦爛 ひやおろし                     さんらん ひやおろし
# 4837         純米 白銀蔵王                  じゅんまい はくぎんざおう
# 8214    大吟醸 生酒 吟のかほり            だいぎんじょう なまざけ ぎんのかほり
# 8415             純天山                        じゅんてんざん
#
#                                        name_romaji sake_type rice_type  \
# 2541  Tokubetsuhonjouzou Namachozoushu Fukushougun    特別本醸造酒       NaN
# 3003                             Sanran Hiyaoroshi       普通酒       NaN
# 4837                            Junmai Hakuginzaou       純米酒       美山錦
# 8214                 Daiginjou Namazake GinnoKaori      大吟醸酒       山田錦
# 8415                                     Juntenzan     特別純米酒       山田錦
#
#      rice_origin yeast  rice_polishing_rate   abv    acidity amino  gravity  \
# 2541         NaN   NaN                  NaN   NaN        NaN   NaN      NaN
# 3003         NaN   NaN                  NaN   NaN        NaN   NaN      NaN
# 4837         長野県   NaN                 70.0  15.3       1.50   NaN      3.0
# 8214         兵庫県   NaN                 40.0  15.0       1.30   NaN      5.0
# 8415         兵庫県   NaN                 60.0  15.0  1.50~1.80  1.70  2.0~3.0
#
#                   volume prefecture city company address website brand  \
# 2541               720ml        NaN  NaN     NaN     NaN     NaN   NaN
# 3003               720ml        NaN  NaN     NaN     NaN     NaN   NaN
# 4837              1800ml        NaN  NaN     NaN     NaN     NaN   NaN
# 8214               300ml        NaN  NaN     NaN     NaN     NaN   NaN
# 8415  1800ml/720ml/300ml        NaN  NaN     NaN     NaN     NaN   NaN
#
#       abv_low  abv_high  abv_avg  acidity_low  acidity_high  acidity_avg  \
# 2541      NaN       NaN      NaN          NaN           NaN          NaN
# 3003      NaN       NaN      NaN          NaN           NaN          NaN
# 4837     15.3      15.3     15.3          1.5           1.5         1.50
# 8214     15.0      15.0     15.0          1.3           1.3         1.30
# 8415     15.0      15.0     15.0          1.5           1.8         1.65
#
#       amino_low  amino_high  amino_avg  gravity_low  gravity_high  gravity_avg
# 2541        NaN         NaN        NaN          NaN           NaN          NaN
# 3003        NaN         NaN        NaN          NaN           NaN          NaN
# 4837        NaN         NaN        NaN          3.0           3.0          3.0
# 8214        NaN         NaN        NaN          5.0           5.0          5.0
# 8415        1.7         1.7        1.7          2.0           3.0          2.5

# %%
# {sake name: company}
missing_brewery_dict = {
    '大吟醸 生酒 吟のかほり': '梅ヶ枝酒造株式会社',
    '純天山': '天山酒造株式会社',
    '純米 白銀蔵王': '嵐山酒造株式会社',
    '燦爛 ひやおろし': '株式会社外池酒造店',
    '特別本醸造 生貯蔵酒 副将軍': '明利酒類株式会社'
}

# %%
def impute_brewery_info(df_sake, dict_missing_brewery):
    for sake, company in dict_missing_brewery.items():
        brewery_info = df_sake[df_sake['company'] == company].iloc[0, 13:18]
        row_index = df_sake[df_sake['name'] == sake].index
        df_sake.loc[row_index, ['prefecture', 'city', 'company', 'address', 'website']] = brewery_info.values
    return df_sake

# %%
df_sake = impute_brewery_info(df_sake, missing_brewery_dict)

# %%
df_sake[df_sake['name'] == '燦爛 ひやおろし']
# Out:
#           name   name_kana        name_romaji sake_type rice_type rice_origin  \
# 3003  燦爛 ひやおろし  さんらん ひやおろし  Sanran Hiyaoroshi       普通酒       NaN         NaN
#
#      yeast  rice_polishing_rate  abv acidity amino gravity volume prefecture  \
# 3003   NaN                  NaN  NaN     NaN   NaN     NaN  720ml        栃木県
#
#      city    company                   address             website brand  \
# 3003  芳賀郡  株式会社外池酒造店  〒321-4216栃木県芳賀郡益子町塙333-1  http://tonoike.jp/   NaN
#
#       abv_low  abv_high  abv_avg  acidity_low  acidity_high  acidity_avg  \
# 3003      NaN       NaN      NaN          NaN           NaN          NaN
#
#       amino_low  amino_high  amino_avg  gravity_low  gravity_high  gravity_avg
# 3003        NaN         NaN        NaN          NaN           NaN          NaN

# %% [markdown]
# ### mislabeled company / location values

# %%
df_sake.groupby("company").name.count().head()
# Out:
# company
# http://59jo.com/                      5
# http://www.koyumitsuru.jp/            3
# https://r.goope.jp/nakagaki-syuzo     7
# あい娘酒造合資会社                            10
# かち鶴酒造株式会社                             9
# Name: name, dtype: int64

# %%
df_sake[df_sake['company'] == 'http://www.koyumitsuru.jp/'].loc[:, ['prefecture', 'city', 'company', 'address', 'website']]
# Out:
#      prefecture       city                     company  \
# 6412        愛知県  小弓鶴酒造株式会社  http://www.koyumitsuru.jp/
# 6413        愛知県  小弓鶴酒造株式会社  http://www.koyumitsuru.jp/
# 6414        愛知県  小弓鶴酒造株式会社  http://www.koyumitsuru.jp/
#
#                         address                     website
# 6412  〒484-0894愛知県犬山市大字羽黒字成海郷70  http://www.koyumitsuru.jp/
# 6413  〒484-0894愛知県犬山市大字羽黒字成海郷70  http://www.koyumitsuru.jp/
# 6414  〒484-0894愛知県犬山市大字羽黒字成海郷70  http://www.koyumitsuru.jp/

# %%
# a few companies have their website in the company column and company in the city column, so these are dictionaries I can use to fix that

company_dict = {
    'https://r.goope.jp/nakagaki-syuzo': '中垣酒造株式会社', # change city to 豊田市 (currently company name)
    'http://59jo.com/': '信州59年醸造会',  # group of 5 brewers from different breweries in Nagano - change city to NA, address is ... Nagano's lat lon?
    'http://www.koyumitsuru.jp/': '小弓鶴酒造株式会社',  # change city to 犬山市 (currently company name)
}

city_dict = {
    '中垣酒造株式会社': '豊田市',
    '小弓鶴酒造株式会社': '犬山市',
    '59醸': np.nan,
}

# %%
df_sake = df_sake.replace({'company': company_dict, 'city': city_dict})

# %%
df_sake[df_sake['company'] == '小弓鶴酒造株式会社']
# Out:
#        name   name_kana        name_romaji sake_type rice_type rice_origin  \
# 6412   山廃原酒    やまはいげんしゅ      YamahaiGenshu      本醸造酒       NaN         NaN
# 6413  小弓鶴上撰  こゆみつるじょうせん  KoyumitsuruJousen      本醸造酒       NaN         NaN
# 6414    琥珀酔       こはくすい          Kohakusui       純米酒       山田錦         兵庫県
#
#      yeast  rice_polishing_rate        abv acidity amino gravity  \
# 6412   NaN                 70.0  19.0~20.0     NaN   NaN     NaN
# 6413   NaN                 70.0  15.0~16.0     NaN   NaN     NaN
# 6414   NaN                 70.0       15.0     NaN   NaN     NaN
#
#             volume prefecture city    company                    address  \
# 6412         720ml        愛知県  犬山市  小弓鶴酒造株式会社  〒484-0894愛知県犬山市大字羽黒字成海郷70
# 6413  1800ml/720ml        愛知県  犬山市  小弓鶴酒造株式会社  〒484-0894愛知県犬山市大字羽黒字成海郷70
# 6414         300ml        愛知県  犬山市  小弓鶴酒造株式会社  〒484-0894愛知県犬山市大字羽黒字成海郷70
#
#                          website       brand  abv_low  abv_high  abv_avg  \
# 6412  http://www.koyumitsuru.jp/  小弓鶴(こゆみつる)     19.0      20.0     19.5
# 6413  http://www.koyumitsuru.jp/  小弓鶴(こゆみつる)     15.0      16.0     15.5
# 6414  http://www.koyumitsuru.jp/  小弓鶴(こゆみつる)     15.0      15.0     15.0
#
#       acidity_low  acidity_high  acidity_avg  amino_low  amino_high  \
# 6412          NaN           NaN          NaN        NaN         NaN
# 6413          NaN           NaN          NaN        NaN         NaN
# 6414          NaN           NaN          NaN        NaN         NaN
#
#       amino_avg  gravity_low  gravity_high  gravity_avg
# 6412        NaN          NaN           NaN          NaN
# 6413        NaN          NaN           NaN          NaN
# 6414        NaN          NaN           NaN          NaN

# %% [markdown]
# ### TODO: missing sake types
# (and start thinking about adding sake type columns - nigori, genshu, nama, shiboritate, etc.)

# %%
df_sake.isna().sum()
# Out:
# name                       0
# name_kana                  0
# name_romaji                3
# sake_type                 52
# rice_type               5767
# rice_origin             5944
# yeast                  12764
# rice_polishing_rate     3681
# abv                     3043
# acidity                 8983
# amino                  12750
# gravity                 6851
# volume                   144
# prefecture                 0
# city                       5
# company                    0
# address                    6
# website                   91
# brand                     35
# abv_low                 3043
# abv_high                3043
# abv_avg                 3043
# acidity_low             8983
# acidity_high            8983
# acidity_avg             8983
# amino_low              12750
# amino_high             12750
# amino_avg              12750
# gravity_low             6851
# gravity_high            6851
# gravity_avg             6851
# prefecture_eng             0
# region                     0
# sake_type_eng             52
# dtype: int64

# %%
df_sake[df_sake.sake_type.isna()]
# Out:
#                         name                           name_kana  \
# 1363                  大吟醸 山王                        だいぎんじょう さんのう
# 3481      とくまる うまくち原酒 20度パック                とくまる うまくちげんしゅ 20どぱっく
# 7913                  綾錦 生原酒                        あやにしき なまげんしゅ
# 7915                 綾錦 にごり酒                         あやにしき にごりしゅ
# 7916                  綾錦 から口                          あやにしき からくち
# 7925                   上撰 原酒                          じょうせん げんしゅ
# 7926                   千徳 金雫                          せんとく きんしずく
# 7927                   千徳 銀雫                          せんとく ぎんしずく
# 7928               冷用生酒 生貯蔵酒                   れいようなまざけ なまちょぞうしゅ
# 7929               さらさら にごり酒                          さらさら にごりしゅ
# 7930                 千徳 にごり酒                          せんとく にごりしゅ
# 7928                        ReiyouNamazake Namachozoushu       NaN       黄金錦
# 7929                                  Sarasara Nigorishu       NaN       NaN
# 7930                                   Sentoku Nigorishu       NaN       山田錦
# 7931                                      Sentoku Seishu       NaN       NaN
# 7932                               HappouSeishu Hajimari       NaN       NaN
# 7933                                              Guzzle       NaN       NaN
# 7935                              Choutokusen Kinpakuiri       NaN       山田錦
# 7936                           Jousen Kotobuki Tsunodaru       NaN       黄金錦
# 7937                                      IchibanShibori       NaN       NaN
# 7938                KuranoMagokoro ShiboritateNamagenshu       NaN       山田錦
# 7939              Shiboritate Namazake(KisetsuGenteishu)       NaN       黄金錦
# 7940                            ReidonoMezame NamaGenshu       NaN       黄金錦
# 7947                          KumamotonoSake Kouro Kasen       NaN       NaN
# 7975                                    Tokusen Hananoka       NaN       NaN
# 7979                                         Hananoka701       NaN       NaN
# 7980                                         Hananoka702       NaN       NaN
# 7989                       Kikunoshiro KikuchiMonogatari       NaN       NaN
# 7991                            Kikunoshiro Shirojirushi       NaN       NaN
# 7992                             Kikunoshiro Kikujirushi       NaN       NaN
# 7993                              Kikunoshiro Nigorizake       NaN       NaN
# 7994                          Kikunoshiro Namazake(Nama)       NaN       NaN
# 7995                      Kikunoshiro Namazake(Namazume)       NaN       NaN
# 7996                       Kikunoshiro ShiboritateGenshu       NaN       NaN
# 8061                                 AsonoYogiri (Spray)       NaN       NaN
# 8080                                     Wada Shiratsuyu       NaN       NaN
# 8081                                         Genshu Hiya       NaN       NaN
# 8140                               ShiboritateNamagenshu       NaN       NaN
# 8163                                 Magatama Nigorizake       NaN       NaN
# 8170                                   Azumatsuyu Kinsen       NaN       NaN
# 8171                                   Azumatsuyu Genshu       NaN       NaN
# 8172                                    Kamenoike Kinsen       NaN       NaN
# 8174                                  Asahinoboru Genshu       NaN       NaN
# 8180                                   Ikkaku NamaGenshu       NaN       NaN
# 8181                                     Ikkaku Namazake       NaN       NaN
# 8257                                  Fukutsuru Sekishin       NaN       NaN
# 8294   TonosamaenoKenjoushu AmakuchiYondanjikomiMurok...       NaN       NaN
# 8371                            Takasago KuradashiGenshu       NaN      レイホウ
# 8373                                        ShironoIzumi       NaN       NaN
# 8551                                        Kurumakagari       NaN       NaN
# 8554                          Yukikabuto JunmaiDaiginjou       NaN       NaN
# 8556                     Eightonepremium Junmaidaiginjou       NaN       NaN
# 8669                                   Nigorizake Yuusen       NaN       NaN
# 8715                                Nabeshima BlackLabel       NaN       NaN
# 11903                         Choumonkyou TezukuriGenshu       NaN       山田錦
#
#       rice_origin       yeast  rice_polishing_rate        abv acidity  amino  \
# 1363          NaN         NaN                  NaN        NaN     NaN    NaN
# 3481          NaN         NaN                 75.0  20.0~21.0     NaN    NaN
# 7913          NaN         NaN                  NaN  19.0~20.0     NaN    NaN
# 7915          NaN         NaN                  NaN        NaN     NaN    NaN
# 7916          NaN         NaN                  NaN        NaN     NaN    NaN
# 7925          愛知県         NaN                 70.0       19.5    1.40    NaN
# 7926          兵庫県         NaN                 70.0       15.2    1.20    NaN
# 7927          兵庫県         NaN                 70.0       14.2    1.20  -3.50
# 8080         〒869-2401阿蘇郡南小国町赤馬場1862                               NaN
# 8081         〒869-2401阿蘇郡南小国町赤馬場1862                               NaN
# 8140        〒854-0056長崎県諫早市土師野尾町17-4         http://www.kinokawa.co.jp
# 8163          〒855-0807長崎県島原市白土町1065  http://www.yamasaki-syuzo.co.jp/
# 8170        〒859-1104長崎県雲仙市吾妻町古城名241                               NaN
# 8171        〒859-1104長崎県雲仙市吾妻町古城名241                               NaN
# 8172       〒859-1323長崎県雲仙市国見町多比良丙811                               NaN
# 8174    〒859-1415長崎県島原市有明町大三東戊1216-1                               NaN
# 8180       〒859-2202長崎県南島原市有家町山川1123     http://www.sake-ikkaku.co.jp/
# 8181       〒859-2202長崎県南島原市有家町山川1123     http://www.sake-ikkaku.co.jp/
# 8257       〒859-5533長崎県平戸市志々伎町1475番地      http://www.fukuda-shuzo.com/
# 8294      〒859-6101長崎県佐世保市江迎町長坂209番地        http://www.sake-honjin.com
# 8371         〒845-0001佐賀県小城市小城町903番地                               NaN
# 8373         〒845-0001佐賀県小城市小城町903番地                               NaN
# 8551                             NaN                               NaN
# 8554             〒940-0031長岡市地蔵1-8-2   http://www.echigo-choryo.co.jp/
# 8556             〒940-0031長岡市地蔵1-8-2   http://www.echigo-choryo.co.jp/
# 8669         〒849-1321佐賀県鹿島市古枝甲599番地       http://www.sachihime.co.jp/
# 8715         〒849-1322佐賀県鹿島市浜町1244-1             http://nabeshima.biz/
# 11903          〒758-0141山口県萩市川上464-1        https://www.chomonkyo.com/
#
#                        brand  abv_low  abv_high  abv_avg  acidity_low  \
# 1363             山王丸(さんおうまる)      NaN       NaN      NaN          NaN
# 3481                北冠(ほっかん)     20.0      21.0     20.5          NaN
# 7913               綾錦(あやにしき)     19.0      20.0     19.5          NaN
# 7915               綾錦(あやにしき)      NaN       NaN      NaN          NaN
# 7916               綾錦(あやにしき)      NaN       NaN      NaN          NaN
# 7925                千徳(せんとく)     19.5      19.5     19.5          1.4
# 7926                千徳(せんとく)     15.2      15.2     15.2          1.2
# 7927                千徳(せんとく)     14.2      14.2     14.2          1.2
# 7928                千徳(せんとく)     12.8      12.8     12.8          1.1
# 7929                千徳(せんとく)     12.0      12.0     12.0          NaN
# 7930                千徳(せんとく)     15.2      15.2     15.2          NaN
# 7931                千徳(せんとく)      NaN       NaN      NaN          NaN
# 7932                千徳(せんとく)      9.0       9.0      9.0          NaN
# 7933                千徳(せんとく)      8.2       8.2      8.2          4.0
# 7935                千徳(せんとく)     15.2      15.2     15.2          1.2
# 7936                千徳(せんとく)     15.2      15.2     15.2          1.2
# 7937                千徳(せんとく)     19.0      19.0     19.0          NaN
# 7938                千徳(せんとく)     17.2      17.2     17.2          NaN
# 7939                千徳(せんとく)     19.2      19.2     19.2          NaN
# 7940                千徳(せんとく)     19.2      19.2     19.2          NaN
# 7947                 香露(こうろ)     15.0      16.0     15.5          1.4
# 7975               花の香(はなのか)     15.0      15.0     15.0          NaN
# 7979               花の香(はなのか)      8.0       8.0      8.0          NaN
# 7980               花の香(はなのか)      8.0       8.0      8.0          NaN
# 7989              菊の城(きくのしろ)      NaN       NaN      NaN          NaN
# 7991              菊の城(きくのしろ)      NaN       NaN      NaN          NaN
# 7992              菊の城(きくのしろ)      NaN       NaN      NaN          NaN
# 7993                     NaN      NaN       NaN      NaN          NaN
# 7994              菊の城(きくのしろ)      NaN       NaN      NaN          NaN
# 7995              菊の城(きくのしろ)      NaN       NaN      NaN          NaN
# 7996              菊の城(きくのしろ)     20.3      20.3     20.3          1.6
# 8061                    れいざん     15.0      15.0     15.0          NaN
# 8080           和田志ら露(わだしらつゆ)      NaN       NaN      NaN          NaN
# 8081                     NaN      NaN       NaN      NaN          NaN
# 8140               杵の川(きのかわ)     19.0      20.0     19.5          NaN
# 8163               まが玉(まがたま)     18.0      18.0     18.0          NaN
# 8170               東露(あずまつゆ)     15.0      15.0     15.0          NaN
# 8171               東露(あずまつゆ)     17.0      18.0     17.5          NaN
# 8172              亀の池(かめのいけ)      NaN       NaN      NaN          NaN
# 8174            あさひ登(あさひのぼる)     19.0      19.0     19.0          NaN
# 8180                一鶴(いっかく)      NaN       NaN      NaN          NaN
# 8181                一鶴(いっかく)      NaN       NaN      NaN          NaN
# 8257                福鶴(ふくつる)      NaN       NaN      NaN          NaN
# 8294                本陣(ほんじん)     19.0      19.0     19.0          NaN
# 8371                高砂(たかさご)     19.0      19.0     19.0          NaN
# 8373                高砂(たかさご)      NaN       NaN      NaN          NaN
# 8551                     NaN      NaN       NaN      NaN          NaN
# 8554               雪兜(ゆきかぶと)      NaN       NaN      NaN          NaN
# 8556   81Premium(えいとわんぷれみあむ)      NaN       NaN      NaN          NaN
# 8669                幸姫(さちひめ)     15.0      15.0     15.0          NaN
# 8715                鍋島(なべしま)     16.0      16.0     16.0          NaN
# 11903          長門峡(ちょうもんきょう)     18.0      19.0     18.5          NaN
#
#        acidity_high  acidity_avg  amino_low  amino_high  amino_avg  \
# 1363            NaN          NaN        NaN         NaN        NaN
# 3481            NaN          NaN        NaN         NaN        NaN
# 7913            NaN          NaN        NaN         NaN        NaN
# 7915            NaN          NaN        NaN         NaN        NaN
# 7916            NaN          NaN        NaN         NaN        NaN
# 7925            1.4          1.4        NaN         NaN        NaN
# 7926            1.2          1.2        NaN         NaN        NaN
# 7927            1.2          1.2       -3.5        -3.5       -3.5
# 7928            1.1          1.1        NaN         NaN        NaN
# 7929            NaN          NaN        NaN         NaN        NaN
# 7930            NaN          NaN        NaN         NaN        NaN
# 7931            NaN          NaN        NaN         NaN        NaN
# 7932            NaN          NaN        NaN         NaN        NaN
# 7933            4.0          4.0        NaN         NaN        NaN
# 7935            1.2          1.2        NaN         NaN        NaN
# 7936            1.2          1.2        NaN         NaN        NaN
# 7937            NaN          NaN        NaN         NaN        NaN
# 7938            NaN          NaN        NaN         NaN        NaN
# 7939            NaN          NaN        NaN         NaN        NaN
# 7940            NaN          NaN        NaN         NaN        NaN
# 7947            1.4          1.4        NaN         NaN        NaN
# 7975            NaN          NaN        NaN         NaN        NaN
# 7979            NaN          NaN        NaN         NaN        NaN
# 7980            NaN          NaN        NaN         NaN        NaN
# 7989            NaN          NaN        NaN         NaN        NaN
# 7991            NaN          NaN        NaN         NaN        NaN
# 7992            NaN          NaN        NaN         NaN        NaN
# 7993            NaN          NaN        NaN         NaN        NaN
# 7994            NaN          NaN        NaN         NaN        NaN
# 7995            NaN          NaN        NaN         NaN        NaN
# 7996            1.6          1.6        NaN         NaN        NaN
# 8061            NaN          NaN        NaN         NaN        NaN
# 8080            NaN          NaN        NaN         NaN        NaN
# 8081            NaN          NaN        NaN         NaN        NaN
# 8140            NaN          NaN        NaN         NaN        NaN
# 8163            NaN          NaN        NaN         NaN        NaN
# 8170            NaN          NaN        NaN         NaN        NaN
# 8171            NaN          NaN        NaN         NaN        NaN
# 8172            NaN          NaN        NaN         NaN        NaN
# 8174            NaN          NaN        NaN         NaN        NaN
# 8180            NaN          NaN        NaN         NaN        NaN
# 8181            NaN          NaN        NaN         NaN        NaN
# 8257            NaN          NaN        NaN         NaN        NaN
# 8294            NaN          NaN        NaN         NaN        NaN
# 8371            NaN          NaN        NaN         NaN        NaN
# 8373            NaN          NaN        NaN         NaN        NaN
# 8551            NaN          NaN        NaN         NaN        NaN
# 8554            NaN          NaN        NaN         NaN        NaN
# 8556            NaN          NaN        NaN         NaN        NaN
# 8669            NaN          NaN        NaN         NaN        NaN
# 8715            NaN          NaN        NaN         NaN        NaN
# 11903           NaN          NaN        NaN         NaN        NaN
#
#        gravity_low  gravity_high  gravity_avg prefecture_eng   region  \
# 1363           NaN           NaN          NaN      Fukushima   Tōhoku
# 3481           NaN           NaN          NaN        Tochigi    Kantō
# 7913           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7915           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7916           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7925          -1.5          -1.5         -1.5       Miyazaki   Kyūshū
# 7926           0.0           0.0          0.0       Miyazaki   Kyūshū
# 7927           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7928           0.0           0.0          0.0       Miyazaki   Kyūshū
# 7929           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7930         -17.0         -17.0        -17.0       Miyazaki   Kyūshū
# 7931           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7932           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7933         -44.0         -44.0        -44.0       Miyazaki   Kyūshū
# 7935           0.0           0.0          0.0       Miyazaki   Kyūshū
# 7936           0.0           0.0          0.0       Miyazaki   Kyūshū
# 7937           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7938           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7939           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7940           NaN           NaN          NaN       Miyazaki   Kyūshū
# 7947          -2.0          -2.0         -2.0       Kumamoto   Kyūshū
# 7975           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7979           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7980           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7989           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7991           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7992           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7993           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7994           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7995           NaN           NaN          NaN       Kumamoto   Kyūshū
# 7996           3.0           3.0          3.0       Kumamoto   Kyūshū
# 8061           NaN           NaN          NaN       Kumamoto   Kyūshū
# 8080           NaN           NaN          NaN       Kumamoto   Kyūshū
# 8081           NaN           NaN          NaN       Kumamoto   Kyūshū
# 8140          -2.0          -2.0         -2.0       Nagasaki   Kyūshū
# 8163          -6.0          -6.0         -6.0       Nagasaki   Kyūshū
# 8170           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8171           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8172           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8174          -3.0          -3.0         -3.0       Nagasaki   Kyūshū
# 8180           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8181           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8257           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8294           NaN           NaN          NaN       Nagasaki   Kyūshū
# 8371          -2.0           0.0         -1.0           Saga   Kyūshū
# 8373           NaN           NaN          NaN           Saga   Kyūshū
# 8551           NaN           NaN          NaN        Niigata    Chūbu
# 8554           NaN           NaN          NaN        Niigata    Chūbu
# 8556           NaN           NaN          NaN        Niigata    Chūbu
# 8669           NaN           NaN          NaN           Saga   Kyūshū
# 8715           NaN           NaN          NaN           Saga   Kyūshū
# 11903          3.0           3.0          3.0      Yamaguchi  Chūgoku
#
#       sake_type_eng
# 1363            NaN
# 3481            NaN
# 7913            NaN
# 7915            NaN
# 7916            NaN
# 7925            NaN
# 7926            NaN
# 7927            NaN
# 7928            NaN
# 7929            NaN
# 7930            NaN
# 7931            NaN
# 7932            NaN
# 7933            NaN
# 7935            NaN
# 7936            NaN
# 7937            NaN
# 7938            NaN
# 7939            NaN
# 7940            NaN
# 7947            NaN
# 7975            NaN
# 7979            NaN
# 7980            NaN
# 7989            NaN
# 7991            NaN
# 7992            NaN
# 7993            NaN
# 7994            NaN
# 7995            NaN
# 7996            NaN
# 8061            NaN
# 8080            NaN
# 8081            NaN
# 8140            NaN
# 8163            NaN
# 8170            NaN
# 8171            NaN
# 8172            NaN
# 8174            NaN
# 8180            NaN
# 8181            NaN
# 8257            NaN
# 8294            NaN
# 8371            NaN
# 8373            NaN
# 8551            NaN
# 8554            NaN
# 8556            NaN
# 8669            NaN
# 8715            NaN
# 11903           NaN

# %%
df_sake[df_sake.company == "越後・謙信SAKEまつり"]

# %% [markdown]
# ## adding columns

# %% [markdown]
# **prefecture, region, and sake type columns in English**

# %%
def get_wikidf_pref():
    # get table from wikipedia
    wikiurl="https://en.wikipedia.org/wiki/Prefectures_of_Japan"
    table_class="wikitable sortable jquery-tablesorter"
    response=requests.get(wikiurl)
    soup = bs(response.text, 'html.parser')
    table=soup.find('table',{'class':"wikitable"})

    # convert table to df
    df_pref=pd.read_html(str(table))
    
    return pd.DataFrame(df_pref[0])

# %%
def get_wikidf_sake_types():
    # get table from wikipedia
    wikiurl="https://en.wikipedia.org/wiki/Sake"
    table_class="wikitable sortable jquery-tablesorter"
    response=requests.get(wikiurl)
    soup = bs(response.text, 'html.parser')
    table=soup.find('table',{'class':"wikitable"})
    
    # convert table to df
    df=pd.read_html(str(table))
    
    return pd.DataFrame(df[0])

# %%
def add_columns(df_sake):
    # get prefecture and sake type dfs
    df_pref = get_wikidf_pref()
    df_sake_types = get_wikidf_sake_types()
    
    # create mapping dictionaries for English names for prefectures, regions, and sake types
    pref_mapping = dict(df_pref[['Prefecture.1', 'Prefecture']].values)
    region_mapping = dict(df_pref[['Prefecture.1', 'Region']].values)
    sake_type_dict = {val[1]: val[0].strip() for val in df_sake_types['Special Designation'].str.replace('(', ',', regex=False).str.split(',').str[:2]}
    
    # add missing sake types to dict
    sake_type_dict['普通酒'] = 'Futsū-shu'
    sake_type_dict['貴醸酒'] = 'Kijō-shu'
    sake_type_dict['純米系'] = 'Junmai-kei'
    sake_type_dict['本醸造系'] = 'Honjōzō-kei'
    
    # add prefecture, region, and sake type columns to df
    df_sake['prefecture_eng'] = df_sake.prefecture.map(pref_mapping)
    df_sake['region'] = df_sake.prefecture.map(region_mapping)
    df_sake['sake_type_eng'] = df_sake.sake_type.map(sake_type_dict)

    return df_sake

# %%
df_sake = add_columns(df_sake)
df_sake.tail(3)
# Out:
#                      name                      name_kana  \
# 14803    無濾過原酒 年魚市 初しぼり生酒          むろかげんしゅ あゆち はつしぼりなまざけ
# 14804      無濾過原酒 年魚市 純米吟醸         むろかげんしゅ あゆち じゅんまいぎんじょう
# 14805  月読みの宴 ひやおろし 純米吟醸原酒  つくよみのうたげ ひやおろし じゅんまいぎんじょうげんしゅ
#
#                                           name_romaji sake_type rice_type  \
# 14803        MurokaGenshu Ayuchi HatsushiboriNamazake     純米吟醸酒       夢山水
# 14804                MurokaGenshu Ayuchi Junmaiginjou     純米吟醸酒       夢山水
# 14805  TsukuyominoUtage Hiyaoroshi JunmaiginjouGenshu     純米吟醸酒       夢山水
#
#       rice_origin yeast  rice_polishing_rate   abv acidity amino gravity  \
# 14803         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
# 14804         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
# 14805         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
#
#              volume prefecture city company                  address  \
# 14803  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14804  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14805  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
#
#                          website     brand  abv_low  abv_high  abv_avg  \
# 14803  https://www.sonnoh.co.jp/  年魚市(あゆち)     17.5      17.5     17.5
# 14804  https://www.sonnoh.co.jp/  年魚市(あゆち)     17.5      17.5     17.5
# 14805  https://www.sonnoh.co.jp/  尊皇(そんのう)     17.5      17.5     17.5
#
#        acidity_low  acidity_high  acidity_avg  amino_low  amino_high  \
# 14803          1.9           1.9          1.9        1.4         1.4
# 14804          1.9           1.9          1.9        1.4         1.4
# 14805          1.9           1.9          1.9        1.4         1.4
#
#        amino_avg  gravity_low  gravity_high  gravity_avg prefecture_eng  \
# 14803        1.4          2.0           2.0          2.0          Aichi
# 14804        1.4          2.0           2.0          2.0          Aichi
# 14805        1.4          2.0           2.0          2.0          Aichi
#
#       region     sake_type_eng
# 14803  Chūbu  Junmai Ginjō-shu
# 14804  Chūbu  Junmai Ginjō-shu
# 14805  Chūbu  Junmai Ginjō-shu

# %% [markdown]
# ## prefecture and company dfs

# %% [markdown]
# ### prefecture df

# %%
df_sake.groupby('prefecture').company.nunique().sum()
# Out:
# 841

# %%
def get_df_prefecture(df_sake):
    df_prefecture = df_sake.groupby('prefecture').agg(
        num_sake = ('name', 'count'), 
        num_company = ('company', 'nunique'),
        abv_avg = ('abv_avg', 'mean'),
        abv_count = ('abv_avg', 'count'),
        abv_std = ('abv_avg', 'std'),
        acidity_avg = ('acidity_avg', 'mean'),
        acidity_count = ('acidity_avg', 'count'),
        acidity_std = ('acidity_avg', 'std'),
        gravity_avg = ('gravity_avg', 'mean'),
        gravity_count = ('gravity_avg', 'count'),
        gravity_std = ('gravity_avg', 'std'),
    )

    df_pref = get_wikidf_pref()
    pref_mapping = dict(df_pref[['Prefecture.1', 'Prefecture']].values)
    region_mapping = dict(df_pref[['Prefecture.1', 'Region']].values)

    df_prefecture['prefecture_eng'] = df_prefecture.index.map(pref_mapping)
    df_prefecture['region'] = df_prefecture.index.map(region_mapping)

    cols = df_prefecture.columns.to_list()
    cols = cols[-2:] + cols[:-2]
    cols

    return df_prefecture[cols]

# %%
df_prefecture = get_df_prefecture(df_sake)
df_prefecture.head()
# Out:
#            prefecture_eng    region  num_sake  num_company    abv_avg  \
# prefecture
# 三重県                   Mie    Kansai       393           25  15.750000
# 京都府                 Kyoto    Kansai       760           35  15.512574
# 佐賀県                  Saga    Kyūshū       460           24  15.978109
# 兵庫県                 Hyōgo    Kansai      1029           54  15.600179
# 北海道              Hokkaido  Hokkaidō       220           10  15.435000
#
#             abv_count   abv_std  acidity_avg  acidity_count  acidity_std  \
# prefecture
# 三重県               298  1.724087     1.575379            132     0.485692
# 京都府               672  1.933465     1.515365            260     0.575453
# 佐賀県               386  1.165124     1.577778            198     0.396381
# 兵庫県               839  1.921093     1.469019            418     0.459854
# 北海道               200  1.285862     1.347863            117     0.168972
#
#             gravity_avg  gravity_count  gravity_std
# prefecture
# 三重県            0.986829            205     8.675081
# 京都府            0.185598            368    10.368969
# 佐賀県            0.861220            254     4.840291
# 兵庫県            1.310603            580     8.054577
# 北海道            3.068182            132     3.599074

# %% [markdown]
# ### company df

# %%
df_sake.tail(3)
# Out:
#                      name                      name_kana  \
# 14803    無濾過原酒 年魚市 初しぼり生酒          むろかげんしゅ あゆち はつしぼりなまざけ
# 14804      無濾過原酒 年魚市 純米吟醸         むろかげんしゅ あゆち じゅんまいぎんじょう
# 14805  月読みの宴 ひやおろし 純米吟醸原酒  つくよみのうたげ ひやおろし じゅんまいぎんじょうげんしゅ
#
#                                           name_romaji sake_type rice_type  \
# 14803        MurokaGenshu Ayuchi HatsushiboriNamazake     純米吟醸酒       夢山水
# 14804                MurokaGenshu Ayuchi Junmaiginjou     純米吟醸酒       夢山水
# 14805  TsukuyominoUtage Hiyaoroshi JunmaiginjouGenshu     純米吟醸酒       夢山水
#
#       rice_origin yeast  rice_polishing_rate   abv acidity amino gravity  \
# 14803         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
# 14804         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
# 14805         愛知県   NaN                 60.0  17.5    1.90  1.40     2.0
#
#              volume prefecture city company                  address  \
# 14803  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14804  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
# 14805  1800ml/720ml        愛知県  西尾市  山崎合資会社  〒444-0703愛知県西尾市西幡豆町柿田57
#
#                          website     brand  abv_low  abv_high  abv_avg  \
# 14803  https://www.sonnoh.co.jp/  年魚市(あゆち)     17.5      17.5     17.5
# 14804  https://www.sonnoh.co.jp/  年魚市(あゆち)     17.5      17.5     17.5
# 14805  https://www.sonnoh.co.jp/  尊皇(そんのう)     17.5      17.5     17.5
#
#        acidity_low  acidity_high  acidity_avg  amino_low  amino_high  \
# 14803          1.9           1.9          1.9        1.4         1.4
# 14804          1.9           1.9          1.9        1.4         1.4
# 14805          1.9           1.9          1.9        1.4         1.4
#
#        amino_avg  gravity_low  gravity_high  gravity_avg prefecture_eng  \
# 14803        1.4          2.0           2.0          2.0          Aichi
# 14804        1.4          2.0           2.0          2.0          Aichi
# 14805        1.4          2.0           2.0          2.0          Aichi
#
#       region     sake_type_eng
# 14803  Chūbu  Junmai Ginjō-shu
# 14804  Chūbu  Junmai Ginjō-shu
# 14805  Chūbu  Junmai Ginjō-shu

# %%
df_company = df_sake.groupby('company').agg(
        num_sake = ('name', 'count'), 
        abv_avg = ('abv_avg', 'mean'),
        abv_count = ('abv_avg', 'count'),
        abv_std = ('abv_avg', 'std'),
        acidity_avg = ('acidity_avg', 'mean'),
        acidity_count = ('acidity_avg', 'count'),
        acidity_std = ('acidity_avg', 'std'),
        gravity_avg = ('gravity_avg', 'mean'),
        gravity_count = ('gravity_avg', 'count'),
        gravity_std = ('gravity_avg', 'std'),
    )


# get prefecture, city, address, and website columns
company_mapping_1 = dict(df_sake[['company', 'prefecture']].values)
company_mapping_2 = dict(df_sake[['company', 'city']].values)
company_mapping_3 = dict(df_sake[['company', 'address']].values)
company_mapping_4 = dict(df_sake[['company', 'website']].values)

df_company['prefecture'] = df_company.index.map(company_mapping_1)
df_company['city'] = df_company.index.map(company_mapping_2)
df_company['address'] = df_company.index.map(company_mapping_3)
df_company['website'] = df_company.index.map(company_mapping_4)

# get prefecture and region columns in English
df_pref = get_wikidf_pref()
pref_mapping = dict(df_pref[['Prefecture.1', 'Prefecture']].values)
region_mapping = dict(df_pref[['Prefecture.1', 'Region']].values)
df_company['region'] = df_company.prefecture.map(region_mapping)
df_company['prefecture_eng'] = df_company.prefecture.map(pref_mapping)

# get lat and lon columns for each company
API_KEY = "AIzaSyD0cQGpbPgM-x-GnN5RxFHSKICq3MtVmI8"
URL = "https://maps.googleapis.com/maps/api/geocode/json"

# rearrange columns
cols = list(df_company.columns)
cols = cols[-2:] + cols[10:11] + cols[11:14] + cols[:10]

df_company = df_company[cols]
df_company.head()
# Out:
#             region prefecture_eng prefecture  city  \
# company
# あい娘酒造合資会社   Kyūshū       Nagasaki        長崎県   雲仙市
# かち鶴酒造株式会社  Shikoku          Ehime        愛媛県   伊予郡
# はざま酒造株式会社    Chūbu           Gifu        岐阜県  中津川市
# ぶんご銘醸株式会社   Kyūshū           Ōita        大分県   佐伯市
# ほまれ酒造株式会社   Tōhoku      Fukushima        福島県  喜多方市
#
#                                    address                        website  \
# company
# あい娘酒造合資会社           〒854-0301長崎県雲仙市愛野町甲137                            NaN
# かち鶴酒造株式会社        〒791-2120愛媛県伊予郡砥部町宮内542番地      http://www.kachizuru.com/
# はざま酒造株式会社       〒508-0041岐阜県中津川市本町4丁目1番51号              http://enasan.jp/
# ぶんご銘醸株式会社  〒879-3105大分県佐伯市直川大字横川字亀の甲789番地4  http://www.bungomeijyo.co.jp/
# ほまれ酒造株式会社     〒966-0902福島県喜多方市松山町村松常盤町2706      http://www.aizuhomare.jp/
#
#            num_sake    abv_avg  abv_count   abv_std  acidity_avg  \
# company
# あい娘酒造合資会社        10  15.500000          1       NaN          NaN
# かち鶴酒造株式会社         9  18.555556          9  1.509231          NaN
# はざま酒造株式会社         5  16.000000          5  0.000000          NaN
# ぶんご銘醸株式会社         3        NaN          0       NaN          NaN
# ほまれ酒造株式会社        25  15.680000         25  1.281926     1.470833
#
#            acidity_count  acidity_std  gravity_avg  gravity_count  gravity_std
# company
# あい娘酒造合資会社              0          NaN         1.00              1          NaN
# かち鶴酒造株式会社              0          NaN         0.50              8     3.854496
# はざま酒造株式会社              0          NaN          NaN              0          NaN
# ぶんご銘醸株式会社              0          NaN          NaN              0          NaN
# ほまれ酒造株式会社             24     0.214637         0.42             25     5.999444

# %%
API_KEY = "AIzaSyD0cQGpbPgM-x-GnN5RxFHSKICq3MtVmI8"
URL = "https://maps.googleapis.com/maps/api/geocode/json"

# %%
for address in df_company.address:
    print(address)
# Out:
# 〒854-0301長崎県雲仙市愛野町甲137
# 〒791-2120愛媛県伊予郡砥部町宮内542番地
# 〒508-0041岐阜県中津川市本町4丁目1番51号
# 〒879-3105大分県佐伯市直川大字横川字亀の甲789番地4
# 〒966-0902福島県喜多方市松山町村松常盤町2706
# 〒675-1192兵庫県加古郡稲美町蛸草321
# 〒612-8081京都府京都市伏見区新町11丁目337-1
# 〒877-0005大分県日田市豆田町6-31
# 〒626-0071京都府宮津市字由良949
# 〒679-4298兵庫県姫路市林田町六九谷681
# 〒719-1175岡山県総社市清音上中島372-1
# 〒694-0064島根県大田市大田町大田ハ271-2
# 〒371-0223群馬県前橋市大胡町12
# 〒441-2301愛知県北設楽郡設楽町田口字町浦22番地
# 〒013-0041秋田県横手市大沢字西野67-2
# 〒985-0057宮城県塩竈市西町3-9
# 〒685-0027島根県隠岐郡隠岐の島町原田174番地
# 〒708-0815岡山県津山市一宮436
# 〒799-2434愛媛県松山市柳原123番地
# 〒880-0833　宮崎市昭栄町45番地1
# 〒496-0915愛知県愛西市本部田町本西60番地
# 〒421-0111静岡県静岡市駿河区丸子新田1-1
# 〒309-1701茨城県笠間市小原2125
# 〒322-0604栃木県栃木市西方町元850
# 〒797-1504愛媛県大洲市肱川町山鳥坂49
# 〒799-1106愛媛県西条市小松町大頭甲312-2
# 〒669-6559兵庫県美方郡香美町香住区小原600-2
# 〒992-0045山形県米沢市中央7-3-10
# 〒731-4215広島県安芸郡熊野町7870
# 〒410-0312静岡県沼津市原354-1
# 〒781-5310高知県香南市赤岡町443
# 〒965-0844福島県会津若松市門田町一ノ堰村東755
# 〒940-0031長岡市地蔵1-8-2
# 〒682-0825鳥取県倉吉市西仲町2633
# 〒781-2141高知県吾川郡いの町勝賀瀬780-2
# 〒070-0030北海道旭川市宮下通17
# 〒999-7781山形県東田川郡庄内町余目興野42
# 〒034-0001青森県十和田市大字三本木字稲吉176-2
# 〒669-2322兵庫県丹波篠山市呉服町73
# 〒324-0057栃木県大田原市住吉町1-1-28
# 〒847-0824佐賀県唐津市神田3272-1
# 〒965-0044福島県会津若松市七日町2番46号
# 〒496-0017愛知県津島市百町字旭46番地
# 〒830-0045福岡県久留米市小頭町8番地12
# 〒999-8231山形県酒田市麓字横道32
# 〒612-8242京都府京都市伏見区横大路下三栖梶原町53
# 〒612-8207京都府京都市伏見区横大路三栖山城屋敷町105
# 〒374-0065群馬県館林市西本町7-13

# %%
gmaps = googlemaps.Client(key=API_KEY)

# Geocoding an address
geocode_result = gmaps.geocode('〒781-0270高知県高知市長浜566-1')

geocode_result
# Out:
# [{'address_components': [{'long_name': '566-1',
#     'short_name': '566-1',
#     'types': ['premise']},
#    {'long_name': 'Nagahama',
#     'short_name': 'Nagahama',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': 'Kochi',
#     'short_name': 'Kochi',
#     'types': ['locality', 'political']},
#    {'long_name': 'Kochi',
#     'short_name': 'Kochi',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Japan',
#     'short_name': 'JP',
#     'types': ['country', 'political']},
#    {'long_name': '781-0270',
#     'short_name': '781-0270',
#     'types': ['postal_code']}],
#   'formatted_address': '566-1 Nagahama, Kochi, 781-0270, Japan',
#   'geometry': {'bounds': {'northeast': {'lat': 33.5016731, 'lng': 133.5494694},
#     'southwest': {'lat': 33.5014062, 'lng': 133.5490427}},
#    'location': {'lat': 33.5015699, 'lng': 133.5493916},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 33.5028886302915,
#      'lng': 133.5506050302915},
#     'southwest': {'lat': 33.5001906697085, 'lng': 133.5479070697085}}},
#   'place_id': 'ChIJmSjcle8ZTjURxNHSA2nGUQA',
#   'types': ['premise']}]

# %%
geocode_result[0].keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'place_id', 'types'])

# %%
geocode_result[0]['geometry']['location']['lat']
# Out:
# 33.5015699

# %%
geocode_result[0]['geometry']['location']['lng']
# Out:
# 133.5493916

# %% [markdown]
# ## streamlit dashboard

# %% [markdown]
# ### load data

# %%
@st.cache
def load_data():
    df_sake = pd.read_csv('../data/sake_list_final.csv').drop(columns="Unnamed: 0")
    return df_sake

df_sake = load_data()

# %% [markdown]
# ## useful code

# %%
# create a mapping dictionary between two columns - two versions

# version 1
dict_company_pref = pd.Series(df_sake['prefecture'].values,index=df_sake.company).to_dict()
dict_company_pref
# Out:
# {'合名会社寒梅酒造': '宮城県',
#  '株式会社新澤醸造店': '宮城県',
#  '森民酒造店': '宮城県',
#  '久保田酒造株式会社': '広島県',
#  '旭鳳酒造株式会社': '広島県',
#  '小野酒造株式会社': '広島県',
#  '會津アクティベートアソシエーション株式会社': '福島県',
#  '有限会社金水晶酒造店': '福島県',
#  '有賀醸造合資会社': '福島県',
#  '馬上酒造場': '広島県',
#  '八幡川酒造株式会社': '広島県',
#  '千駒酒造株式会社': '福島県',
#  '株式会社小泉本店': '広島県',
#  '合名会社梅田酒造場': '広島県',
#  '株式会社三宅本店': '広島県',
#  '大谷忠吉本店': '福島県',
#  '白河銘醸株式会社': '福島県',
#  '相原酒造株式会社': '広島県',
#  '笹の川酒造株式会社': '福島県',
#  '榎酒造株式会社': '広島県',
#  '林酒造株式会社': '岐阜県',
#  '江田島銘醸株式会社': '広島県',
#  '有限会社仁井田本家': '福島県',
#  '玄葉本店': '福島県',
#  '株式会社矢澤酒造店': '福島県',
#  '佐藤酒造株式会社': '滋賀県',
#  '若清水酒造株式会社': '福島県',
#  '中国醸造株式会社': '広島県',
#  '賀茂泉酒造株式会社': '広島県',
#  '豊国酒造合資会社': '福島県',
#  '亀齢酒造株式会社': '広島県',
#  '若関酒造株式会社': '福島県',
#  '人気酒造株式会社': '福島県',
#  '白牡丹酒造株式会社': '広島県',
#  '福美人酒造株式会社': '広島県',
#  '賀茂鶴酒造株式会社': '広島県',
#  '奥の松酒造株式会社': '福島県',
#  '大七酒造株式会社': '福島県',
#  '株式会社檜物屋酒造店': '福島県',
#  '山口合名会社酒造': '福島県',
#  '合資会社辰泉酒造': '福島県',
#  '鶴乃江酒造株式会社': '福島県',
#  '花春酒造株式会社': '福島県',
#  '山陽鶴酒造株式会社': '広島県',
#  '名倉山酒造株式会社': '福島県',
#  '高橋庄作酒造店': '福島県',
#  '末廣酒造株式会社': '福島県',
#  '有限会社板野酒造場': '岡山県',
#  '株式会社板野酒造本店': '岡山県',
#  '利守酒造株式会社': '岡山県',
#  '宮泉銘醸株式会社': '福島県',
#  '夢心酒造株式会社': '福島県',
#  '小原酒造株式会社': '福島県',
#  '小坂酒造株式会社': '岡山県',
#  '宮下酒造株式会社': '岡山県',
#  '有限会社田中酒造場': '岡山県',
#  '株式会社牧野酒造本店': '岡山県',
#  '難波酒造株式会社': '岡山県',
#  '合資会社多胡本家酒造場': '岡山県',
#  '金剛酒造株式会社': '岡山県',
#  '赤磐酒造株式会社': '岡山県',
#  '室町酒造株式会社': '岡山県',
#  '峰の雪酒造場': '福島県',
#  '合資会社大和川酒造店': '福島県',
#  '喜多の華酒造場': '福島県',
#  'ほまれ酒造株式会社': '福島県',
#  '森田酒造株式会社': '岡山県',
#  '笹正宗酒造株式会社': '福島県',
#  '十八盛酒造株式会社': '岡山県',
#  '三冠酒造有限会社': '岡山県',
#  '国権酒造株式会社': '福島県',
#  '有限会社渡辺酒造本店': '岡山県',
#  '開当男山酒造': '福島県',
#  '菊池酒造株式会社': '岡山県',
#  '嘉美心酒造株式会社': '岡山県',
#  '山成酒造株式会社': '岡山県',
#  '会津酒造株式会社': '福島県',
#  '花泉酒造合名会社': '福島県',
#  '大木代吉本店': '福島県',
#  '大天狗酒造': '福島県',
#  '合資会社稲川酒造店': '福島県',
#  '白菊酒造株式会社': '岡山県',
#  '赤木酒造株式会社': '岡山県',
#  '芳烈酒造株式会社': '岡山県',
#  '株式会社落酒造場': '岡山県',
#  '磐梯酒造株式会社': '福島県',
#  '榮川酒造株式会社': '福島県',
#  '大美酒造有限会社': '岡山県',
#  '神露酒造株式会社': '岡山県',
#  '株式会社辻本店': '岡山県',
#  '曙酒造合資会社': '福島県',
#  '丸本酒造株式会社': '岡山県',
#  '平喜酒造株式会社': '岡山県',
#  '太平桜酒造合資会社': '福島県',
#  '株式会社鈴木酒造店': '福島県',
#  '男山酒造株式会社': '山形県',
#  '磯千鳥酒造株式会社': '岡山県',
#  '月山酒造株式会社': '山形県',
#  '松永酒造株式会社': '岡山県',
#  '三宅酒造株式会社': '岡山県',
#  'ヨイキゲン株式会社': '岡山県',
#  '寿虎屋酒造株式会社': '山形県',
#  '三光正宗株式会社': '岡山県',
#  '隠岐酒造株式会社': '島根県',
#  '古澤酒造株式会社': '山形県',
#  '千代寿虎屋株式会社': '山形県',
#  '梅乃宿酒造株式会社': '奈良県',
#  '油長酒造株式会社': '奈良県',
#  '村井醸造株式會社': '茨城県',
#  '株式会社西岡本店': '茨城県',
#  '来福酒造株式会社': '茨城県',
#  '千代酒造株式会社': '奈良県',
#  '葛城酒造株式会社': '奈良県',
#  '株式会社北岡本店': '奈良県',
#  '北村酒造株式会社': '奈良県',
#  '美吉野醸造株式会社': '奈良県',
#  '都美人酒造株式会社': '兵庫県',
#  '株式会社田中酒造店': '宮城県',
#  '竹村酒造店': '茨城県',
#  '千年一酒造株式会社': '兵庫県',
#  '青木酒造株式会社': '愛知県',
#  '萩原酒造株式会社': '茨城県',
#  '株式会社武勇': '茨城県',
#  '結城酒造株式会社': '茨城県',
#  '株式会社笹目宗兵衛商店': '茨城県',
#  '磯蔵酒造有限会社': '茨城県',
#  '金盃酒造株式会社': '兵庫県',
#  '沢の鶴株式会社': '兵庫県',
#  '須藤本家株式会社': '茨城県',
#  '吉久保酒造株式会社': '茨城県',
#  '株式会社小山本家酒造 灘浜福鶴蔵': '兵庫県',
#  '櫻正宗株式会社': '兵庫県',
#  '明利酒類株式会社': '茨城県',
#  '木内酒造合資会社': '茨城県',
#  '檜山酒造株式会社': '茨城県',
#  '株式会社月の井酒造店': '茨城県',
#  '愛友酒造株式会社': '茨城県',
#  '岡部合名会社': '茨城県',
#  '太陽酒造株式会社': '兵庫県',
#  '江井ヶ嶋酒造株式会社': '兵庫県',
#  '西海酒造株式会社': '兵庫県',
#  '龍神酒造株式会社': '群馬県',
#  '清水屋酒造有限会社': '群馬県',
#  '茨木酒造合名会社': '兵庫県',
#  '合名会社岡田本家': '兵庫県',
#  '井澤本家合名会社': '兵庫県',
#  'キング醸造株式会社': '兵庫県',
#  '松屋酒造株式会社': '群馬県',
#  '近藤酒造株式会社': '群馬県',
#  '米田酒造株式会社': '島根県',
#  '株式会社小嶋総本店': '山形県',
#  '香坂酒造株式会社': '山形県',
#  '國暉酒造株式会社': '島根県',
#  '李白酒造有限会社': '島根県',
#  '米鶴酒造株式会社': '山形県',
#  '東の麓酒造有限会社': '山形県',
#  '株式会社竹下本店': '島根県',
#  '株式会社酒持田本店': '島根県',
#  '出羽桜酒造株式会社': '山形県',
#  '天界酒造株式会社': '島根県',
#  '金鳳酒造有限会社': '島根県',
#  '吉田酒造株式会社': '大阪府',
#  '株式会社水戸部酒造': '山形県',
#  '株式会社小屋酒造': '山形県',
#  '亀の井酒造株式会社': '山形県',
#  '竹の露合資会社': '山形県',
#  '板倉酒造有限会社': '島根県',
#  '一宮酒造有限会社': '島根県',
#  '加茂福酒造株式会社': '島根県',
#  '玉櫻酒造有限会社': '島根県',
#  '株式会社岡田屋本店': '島根県',
#  '王祿酒造有限会社': '島根県',
#  '木次酒造株式会社': '島根県',
#  '冨士酒造株式会社': '山形県',
#  '奥出雲酒造株式会社': '島根県',
#  '簸上清酒合名会社': '島根県',
#  '加藤嘉八郎酒造株式会社': '山形県',
#  '株式会社渡會本店': '山形県',
#  '羽根田酒造株式会社': '山形県',
#  '酒田酒造株式会社': '山形県',
#  '菊勇株式会社': '山形県',
#  '若林酒造有限会社': '島根県',
#  '株式会社オードヴィ庄内': '山形県',
#  '日本海酒造株式会社': '島根県',
#  '古橋酒造株式会社': '島根県',
#  '華泉酒造合資会社': '島根県',
#  '東北銘醸株式会社': '山形県',
#  '中川酒造株式会社': '鳥取県',
#  '有限会社太田酒造場': '鳥取県',
#  '藤井酒造合資会社': '鳥取県',
#  '高田酒造株式会社': '鳥取県',
#  '元帥酒造株式会社': '鳥取県',
#  '中井酒造株式会社': '鳥取県',
#  '嵐山酒造株式会社': '山形県',
#  '株式会社稲田本店': '鳥取県',
#  '千代むすび酒造株式会社': '鳥取県',
#  '若乃井酒造株式会社': '山形県',
#  '野沢酒造店': '山形県',
#  '合資会社後藤酒造店': '山形県',
#  '和田酒造合資会社': '山形県',
#  '有限会社山根酒造場': '鳥取県',
#  '朝日川酒造株式会社': '山形県',
#  '株式会社六歌仙': '山形県',
#  '楯の川酒造株式会社': '山形県',
#  '福羅酒造株式会社': '鳥取県',
#  '諏訪酒造株式会社': '鳥取県',
#  '梅津酒造有限会社': '鳥取県',
#  '株式会社江原酒造本店': '鳥取県',
#  '大谷酒造株式会社': '鳥取県',
#  '有限会社大岩酒造本店': '鳥取県',
#  '初光酒造株式会社': '和歌山県',
#  '通宝酒造株式会社': '和歌山県',
#  '平和酒造株式会社': '和歌山県',
#  '天長島村酒造株式会社': '和歌山県',
#  '株式会社世界一統': '和歌山県',
#  '田端酒造株式会社': '和歌山県',
#  '株式会社名手酒造店': '和歌山県',
#  '中野ＢＣ株式会社': '和歌山県',
#  '松山酒造株式会社': '山形県',
#  '合名会社佐藤佐治右衛門': '山形県',
#  '岸野酒造本家': '和歌山県',
#  '鈴木宗右衛門酒造株式会社': '和歌山県',
#  '尾崎酒造株式会社': '青森県',
#  '株式会社九重雜賀': '和歌山県',
#  '鯉川酒造株式会社': '山形県',
#  '麓井酒造株式会社': '山形県',
#  '合資会社杉勇蕨岡酒造場': '山形県',
#  '株式会社吉村秀雄商店': '和歌山県',
#  '初桜酒造株式会社': '和歌山県',
#  '株式会社中本酒造店': '奈良県',
#  '上田酒造株式会社': '奈良県',
#  '合資会社高橋酒造店': '山形県',
#  '菊司醸造株式会社': '奈良県',
#  '八木酒造株式会社': '奈良県',
#  '株式会社今西清兵衛商店': '奈良県',
#  '奈良豊澤酒造株式会社': '奈良県',
#  '増田酒造株式会社': '奈良県',
#  '合資会社浦里酒造店': '茨城県',
#  '稲田酒造合名会社': '奈良県',
#  '倉本酒造株式会社': '奈良県',
#  '西田酒造株式会社': '奈良県',
#  '今西酒造株式会社': '奈良県',
#  '西内酒造': '奈良県',
#  '株式会社久保本家酒造': '奈良県',
#  '芳村酒造株式会社': '奈良県',
#  '株式会社山中酒造店': '茨城県',
#  '喜多酒造株式会社': '滋賀県',
#  '長龍酒造株式会社': '奈良県',
#  '野村酒造株式会社': '茨城県',
#  '太田商店': '奈良県',
#  '五條酒造株式会社': '奈良県',
#  '株式会社山本本家': '京都府',
#  '藤村酒造株式会社': '奈良県',
#  '澤田酒造株式会社': '愛知県',
#  '株式会社大倉本家': '奈良県',
#  '中谷酒造株式会社': '奈良県',
#  '稲葉酒造場': '茨城県',
#  '山崎合資会社': '愛知県',
#  '中垣酒造株式会社': '愛知県',
#  '合資会社柴田酒造場': '愛知県',
#  '相生ユニビオ株式会社': '愛知県',
#  '神杉酒造株式会社': '愛知県',
#  '永井酒造場': '愛知県',
#  '清洲桜醸造株式会社': '愛知県',
#  '山盛酒造株式会社': '愛知県',
#  '神の井酒造株式会社': '愛知県',
#  '株式会社萬乗醸造': '愛知県',
#  '金虎酒造株式会社': '愛知県',
#  '東春酒造株式会社': '愛知県',
#  '浦野合資会社': '愛知県',
#  '原田酒造合資会社': '愛知県',
#  '丸一酒造株式会社': '愛知県',
#  '豊田酒造株式会社': '愛知県',
#  '盛田金しゃち酒造株式会社': '愛知県',
#  '木屋正酒造合資会社': '三重県',
#  '中埜酒造株式会社': '愛知県',
#  '盛田株式会社': '愛知県',
#  '勲碧酒造株式会社': '愛知県',
#  '山星酒造株式会社': '愛知県',
#  '小弓鶴酒造株式会社': '愛知県',
#  '東洋自慢酒造株式会社': '愛知県',
#  '金銀花酒造株式会社': '愛知県',
#  '内藤醸造株式会社': '愛知県',
#  '鶴見酒造株式会社': '愛知県',
#  '山忠本家酒造株式会社': '愛知県',
#  '水谷酒造株式会社': '愛知県',
#  '山田酒造株式会社': '愛知県',
#  '甘強酒造株式会社': '愛知県',
#  '高嶋酒造株式会社': '静岡県',
#  '万大醸造合資会社': '静岡県',
#  '富士正酒造合資会社': '静岡県',
#  '牧野酒造合資会社': '静岡県',
#  '富士錦酒造株式会社': '静岡県',
#  '静岡平喜酒造株式会社': '静岡県',
#  '英君酒造株式会社': '静岡県',
#  '株式会社神沢川酒造場': '静岡県',
#  '三和酒造株式会社': '静岡県',
#  '磯自慢酒造株式会社': '静岡県',
#  '杉井酒造': '静岡県',
#  '株式会社志太泉酒造': '静岡県',
#  '浜松酒造株式会社': '静岡県',
#  '花の舞酒造株式会社': '静岡県',
#  '株式会社土井酒造場': '静岡県',
#  '千寿酒造株式会社': '静岡県',
#  '森本酒造合資会社': '静岡県',
#  '日本泉酒造株式会社': '岐阜県',
#  '杉原酒造株式会社': '岐阜県',
#  '池田屋酒造株式会社': '岐阜県',
#  '合資会社白木恒助商店': '岐阜県',
#  '有限会社松井屋酒造場': '岐阜県',
#  '株式会社小坂酒造場': '岐阜県',
#  '平野醸造合資会社': '岐阜県',
#  '布屋 原酒造場': '岐阜県',
#  '千代菊株式会社': '岐阜県',
#  '渡辺酒造醸': '岐阜県',
#  '武内合資会社': '岐阜県',
#  '株式会社三輪酒造': '岐阜県',
#  '玉泉堂酒造株式会社': '岐阜県',
#  '小町酒造株式会社': '岐阜県',
#  '株式会社林本店': '岐阜県',
#  '御代桜醸造株式会社': '岐阜県',
#  '合資会社山田商店': '岐阜県',
#  '花盛酒造株式会社': '岐阜県',
#  '有限会社平瀬酒造店': '岐阜県',
#  '二木酒造株式会社': '岐阜県',
#  '有限会社原田酒造場': '岐阜県',
#  '株式会社老田酒造店': '岐阜県',
#  '有限会社舩坂酒造店': '岐阜県',
#  '有限会社大坪酒造店': '岐阜県',
#  '株式会社三千盛': '岐阜県',
#  'はざま酒造株式会社': '岐阜県',
#  '菊川株式会社': '岐阜県',
#  '平和錦酒造株式会社': '岐阜県',
#  '白扇酒造株式会社': '岐阜県',
#  '奥飛騨酒蔵株式会社': '岐阜県',
#  '有限会社渡辺酒造店': '岐阜県',
#  '若葉株式会社': '岐阜県',
#  '岩村醸造株式会社': '岐阜県',
#  '有限会社大橋酒造': '岐阜県',
#  '山内酒造株式会社': '岐阜県',
#  '信州59年醸造会': '長野県',
#  '株式会社よしのや': '長野県',
#  '株式会社松葉屋本店': '長野県',
#  '株式会社玉村本店': '長野県',
#  '株式会社東飯田酒造店': '長野県',
#  '株式会社西飯田酒造店': '長野県',
#  '株式会社遠藤酒造場': '長野県',
#  '株式会社丸世酒造店': '長野県',
#  '志賀泉酒造株式会社': '長野県',
#  '天領誉酒造株式会社': '長野県',
#  '大塚酒造株式会社': '長野県',
#  '橘倉酒造株式会社': '長野県',
#  '朝日酒造株式会社': '新潟県',
#  '酔鯨酒造株式会社': '高知県',
#  '泰石酒造株式会社': '沖縄県',
#  '濵田酒造株式会社': '鹿児島県',
#  '雲海酒造株式会社': '宮崎県',
#  '千徳酒造株式会社': '宮崎県',
#  '熊本県酒造研究所': '熊本県',
#  '千代の園酒造株式会社': '熊本県',
#  '花の香酒造株式会社': '熊本県',
#  '株式会社菊の城本舗': '熊本県',
#  '通潤酒造株式会社': '熊本県',
#  '瑞鷹株式会社': '熊本県',
#  '山村酒造合名会社': '熊本県',
#  '室原合名会社': '熊本県',
#  '河津酒造株式会社': '熊本県',
#  '亀萬酒造合資会社': '熊本県',
#  '重家酒造株式会社': '長崎県',
#  '壱岐の蔵酒造株式会社': '長崎県',
#  '河内酒造合名会社': '長崎県',
#  '株式会社杵の川': '長崎県',
#  'あい娘酒造合資会社': '長崎県',
#  '合資会社山崎本店酒造場': '長崎県',
#  '西牟田酒造株式会社': '長崎県',
#  '合資会社伊藤酒造場': '長崎県',
#  '合資会社太田酒造場': '長崎県',
#  '合資会社加藤酒造場': '長崎県',
#  '浦川酒造合資会社': '長崎県',
#  '合資会社吉田屋': '長崎県',
#  '梅ヶ枝酒造株式会社': '長崎県',
#  '今里酒造株式会社': '長崎県',
#  '有限会社森酒造場': '長崎県',
#  '福田酒造株式会社': '長崎県',
#  '潜龍酒造株式会社': '長崎県',
#  '大和酒造株式会社': '佐賀県',
#  '有限会社吉武酒造場': '佐賀県',
#  '合資会社基山商店': '佐賀県',
#  '井出酒造有限会社': '佐賀県',
#  '宗政酒造株式会社': '佐賀県',
#  '小柳酒造株式会社': '佐賀県',
#  '天山酒造株式会社': '佐賀県',
#  '東鶴酒造株式会社': '佐賀県',
#  '鳴滝酒造株式会社': '佐賀県',
#  '合名会社樋渡酒造場': '佐賀県',
#  '古伊万里酒造有限会社': '佐賀県',
#  '越後・謙信SAKEまつり': '新潟県',
#  '天吹酒造合資会社': '佐賀県',
#  '高橋酒造株式会社': '新潟県',
#  '有限会社ニ世古酒造': '北海道',
#  '美の川酒造': '新潟県',
#  '越銘醸株式会社': '新潟県',
#  '窓乃梅酒造株式会社': '佐賀県',
#  '矢野酒造株式会社': '佐賀県',
#  '有限会社 馬場酒造場': '佐賀県',
#  '幸姫酒造 株式会社': '佐賀県',
#  '合資会社 光武酒造場': '佐賀県',
#  '田中酒造株式会社': '北海道',
#  '株式会社 峰松酒造場': '佐賀県',
#  '富久千代酒造有限会社': '佐賀県',
#  '日本清酒株式会社': '北海道',
#  '五町田酒造株式会社': '佐賀県',
#  '瀬頭酒造株式会社': '佐賀県',
#  '小松酒造株式会社': '佐賀県',
#  '株式会社松尾酒造場': '佐賀県',
#  '松浦一酒造株式会社': '佐賀県',
#  '溝上酒造株式会社': '福岡県',
#  '無法松酒造有限会社': '福岡県',
#  '花関酒造株式会社': '福岡県',
#  '株式会社 小林酒造本店': '福岡県',
#  '光酒造株式会社': '福岡県',
#  '翁酒造株式会社': '福岡県',
#  '小林酒造株式会社': '北海道',
#  '髙砂酒造株式会社': '北海道',
#  '豊村酒造有限会社': '福岡県',
#  '勝屋酒造合名会社': '福岡県',
#  '合資会社伊豆本店': '福岡県',
#  '金滴酒造株式会社': '北海道',
#  '石蔵酒造株式会社': '福岡県',
#  '綾杉酒造場': '福岡県',
#  '大賀酒造株式会社': '福岡県',
#  '浜地酒造株式会社': '福岡県',
#  '有限会社白糸酒造': '福岡県',
#  '瑞穂菊酒造株式会社': '福岡県',
#  '寒北斗酒造株式会社': '福岡県',
#  '大里酒造株式会社': '福岡県',
#  '林龍平酒造場': '福岡県',
#  '国稀酒造株式会社': '北海道',
#  '合同酒精株式会社': '東京都',
#  '鷹正宗株式会社': '福岡県',
#  '福徳長酒類株式会社': '千葉県',
#  '男山株式会社': '北海道',
#  '池亀酒造株式会社': '福岡県',
#  '萬年亀酒造株式会社': '福岡県',
#  '株式会社杜の蔵': '福岡県',
#  '旭菊酒造株式会社': '福岡県',
#  '比翼鶴酒造株式会社': '福岡県',
#  '千年乃松酒造株式会社': '福岡県',
#  '合名会社山口酒造場': '福岡県',
#  '福司酒造株式会社': '北海道',
#  '山の壽酒造株式会社': '福岡県',
#  '筑紫の誉酒造株式会社': '福岡県',
#  '若波酒造合名会社': '福岡県',
#  '株式会社蔵内堂': '福岡県',
#  '柳川酒造株式会社': '福岡県',
#  '碓氷勝三郎商店': '北海道',
#  '八戸酒類株式会社': '青森県',
#  '株式会社喜多屋': '福岡県',
#  '株式会社高橋商店': '福岡県',
#  '旭松酒造株式会社': '福岡県',
#  '菊美人酒造株式会社': '福岡県',
#  '八戸酒造株式会社': '青森県',
#  '江頭酒造合資会社': '福岡県',
#  '朝倉酒造株式会社': '福岡県',
#  '森山酒造株式会社': '福岡県',
#  '株式会社篠崎': '福岡県',
#  '鳩正宗株式会社': '青森県',
#  '株式会社鳴海醸造店': '青森県',
#  '株式会社丸竹酒造店': '青森県',
#  '片岡酒造': '福岡県',
#  '合資会社若竹屋酒造場': '福岡県',
#  '白神酒造株式会社': '青森県',
#  '六花酒造株式会社': '青森県',
#  '久保酒蔵株式会社': '大分県',
#  '大分銘醸株式会社': '大分県',
#  '弘前銘醸株式会社': '青森県',
#  '株式会社カネタ玉田酒造店': '青森県',
#  '有限会社中野酒造': '大分県',
#  '萱島酒造有限会社': '大分県',
#  '株式会社久家本店': '大分県',
#  '小手川酒造株式会社': '大分県',
#  '藤居酒造株式会社': '大分県',
#  '大地酒造合資会社': '大分県',
#  'クンチョウ酒造株式会社': '大分県',
#  '三浦酒造株式会社': '青森県',
#  '株式会社井上酒造': '大分県',
#  '老松酒造株式会社': '大分県',
#  '西の誉銘醸株式会社': '大分県',
#  '三和酒類株式会社': '大分県',
#  'ぶんご銘醸株式会社': '大分県',
#  '八鹿酒造株式会社': '大分県',
#  '株式会社齋藤酒造': '青森県',
#  '有限会社麻生本店': '大分県',
#  '浜嶋酒造合資会社': '大分県',
#  '株式会社西田酒造店': '青森県',
#  '有限会社竹浪酒造店': '青森県',
#  '株式会社菊駒酒造': '青森県',
#  '桃川株式会社': '青森県',
#  '水口酒造株式会社': '愛媛県',
#  '株式会社盛田庄兵衛': '青森県',
#  '後藤酒造株式会社': '愛媛県',
#  '新政酒造株式会社': '秋田県',
#  '栄光酒造株式会社': '愛媛県',
#  '島田酒造株式会社': '愛媛県',
#  'かち鶴酒造株式会社': '愛媛県',
#  '協和酒造株式会社': '愛媛県',
#  '秋田酒類製造株式会社': '秋田県',
#  '酒六酒造株式会社': '愛媛県',
#  '石鎚酒造株式会社': '愛媛県',
#  '株式会社八木酒造部': '愛媛県',
#  '千代の亀酒造株式会社': '愛媛県',
#  '秋田酒造株式会社': '秋田県',
#  '梅美人酒造株式会社': '愛媛県',
#  '松田酒造株式会社': '愛媛県',
#  '株式会社元見屋酒店': '愛媛県',
#  '株式会社那波商店': '秋田県',
#  '養老酒造株式会社': '愛媛県',
#  '名門サカイ株式会社': '愛媛県',
#  '西本酒造株式会社': '愛媛県',
#  '梅錦山川株式会社': '愛媛県',
#  '首藤酒造株式会社': '愛媛県',
#  '武田酒造株式会社': '愛媛県',
#  '成龍酒造株式会社': '愛媛県',
#  '両関酒造株式会社': '秋田県',
#  '秋田銘醸株式会社': '秋田県',
#  '桜うづまき酒造株式会社': '愛媛県',
#  '雪雀酒造株式会社': '愛媛県',
#  '綾菊酒造株式会社': '香川県',
#  '勇心酒造株式会社': '香川県',
#  '株式会社森國酒造': '香川県',
#  '西野金陵株式会社': '香川県',
#  '木村酒造': '秋田県',
#  '有限会社斎藤酒造場': '徳島県',
#  '吉本醸造株式会社': '徳島県',
#  '株式会社勢玉': '徳島県',
#  '日新酒類株式会社太閤酒造場': '徳島県',
#  '秋田県醗酵工業株式会社': '秋田県',
#  '阿桜酒造株式会社': '秋田県',
#  '司菊酒造株式会社': '徳島県',
#  '浅舞酒造株式会社': '秋田県',
#  '花乃春酒造株式会社': '徳島県',
#  '津乃峰酒造株式会社': '徳島県',
#  '三芳菊酒造株式会社': '徳島県',
#  '合名会社中和商店': '徳島県',
#  '株式会社本家松浦酒造場': '徳島県',
#  '近清酒造': '徳島県',
#  '芳水酒造有限会社': '徳島県',
#  '舞鶴酒造株式会社': '秋田県',
#  '八重寿銘醸株式会社': '秋田県',
#  '鈴木酒造店': '秋田県',
#  '八百新酒造株式会社': '山口県',
#  '酒井酒造株式会社': '山口県',
#  '五井酒造店': '秋田県',
#  '出羽鶴酒造株式会社': '秋田県',
#  '金紋秋田酒造株式会社': '秋田県',
#  '秋田誉酒造株式会社': '秋田県',
#  '有限会社堀江酒場': '山口県',
#  '村重酒造株式会社': '山口県',
#  '株式会社 齋彌酒造店': '秋田県',
#  '旭酒造株式会社': '三重県',
#  '株式会社佐藤酒造店': '秋田県',
#  '天寿酒造株式会社': '秋田県',
#  '喜久水酒造合資会社': '秋田県',
#  '株式会社北鹿': '秋田県',
#  '亀泉酒造株式会社': '高知県',
#  '高知酒造株式会社': '高知県',
#  '株式会社飛良泉本舗': '秋田県',
#  '小玉醸造株式会社': '秋田県',
#  '土佐酒造株式会社': '高知県',
#  '福禄寿酒造株式会社': '秋田県',
#  '高木酒造株式会社': '高知県',
#  '有限会社仙頭酒造場': '高知県',
#  '有限会社濵川商店': '高知県',
#  '土佐鶴酒造株式会社': '高知県',
#  '山本合名会社': '秋田県',
#  '菊水酒造株式会社': '高知県',
#  '千歳盛酒造株式会社': '秋田県',
#  '株式会社無手無冠': '高知県',
#  '藤娘酒造株式会社': '高知県',
#  '日の丸醸造株式会社': '秋田県',
#  '司牡丹酒造株式会社': '高知県',
#  '八千代酒造合名会社': '山口県',
#  '合名会社栗林酒造店': '秋田県',
#  '株式会社高橋酒造店': '秋田県',
#  '刈穂酒造株式会社': '秋田県',
#  '有限会社西岡酒造店': '高知県',
#  '金分銅酒造株式会社': '山口県',
#  '株式会社はつもみぢ': '山口県',
#  '株式会社山縣本店': '山口県',
#  '男自慢酒造株式会社': '山口県',
#  '新谷酒造株式会社': '山口県',
#  '下関酒造株式会社': '山口県',
#  '福乃友酒造株式会社': '秋田県',
#  '山城屋酒造株式会社': '山口県',
#  '大嶺酒造株式会社': '山口県',
#  '金光酒造株式会社': '山口県',
#  '永山酒造合名会社': '山口県',
#  '中村酒造株式会社': '山口県',
#  '有限会社奥田酒造店': '秋田県',
#  '株式会社桜顔酒造': '岩手県',
#  '株式会社あさ開': '岩手県',
#  '岩崎酒造株式会社': '山口県',
#  '有限会社岡崎酒造場': '山口県',
#  '赤武酒造株式会社': '岩手県',
#  '菊の司酒造株式会社': '岩手県',
#  '株式会社永山本家酒造場': '山口県',
#  '三輪酒造株式会社': '広島県',
#  '株式会社天寶一': '広島県',
#  '両磐酒造株式会社': '岩手県',
#  '世嬉の一酒造株式会社': '岩手県',
#  '株式会社吉源酒造場': '広島県',
#  '酔仙酒造株式会社': '岩手県',
#  '濱岡酒造株式会社': '広島県',
#  '株式会社醉心山根本店': '広島県',
#  '喜久盛酒造': '岩手県',
#  '株式会社浜千鳥': '岩手県',
#  '株式会社菱屋酒造店': '岩手県',
#  '金光酒造合資会社': '広島県',
#  '泉金酒造株式会社': '岩手県',
#  '上閉伊酒造株式会社': '岩手県',
#  '有限会社月の輪酒造店': '岩手県',
#  '廣田酒造店': '岩手県',
#  '合名会社吾妻嶺酒造店': '岩手県',
#  '株式会社南部美人': '岩手県',
#  '株式会社わしの尾': '岩手県',
#  '株式会社福来': '岩手県',
#  '磐乃井酒造株式会社': '岩手県',
#  '岩手銘醸株式会社': '岩手県',
#  '株式会社千松島': '宮城県',
#  '仙台伊澤家勝山酒造株式会社': '宮城県',
#  '合資会社内ヶ崎酒造店': '宮城県',
#  '大和蔵酒造株式会社': '宮城県',
#  '株式会社中勇酒造店': '宮城県',
#  '森民酒造本家': '宮城県',
#  '浦霞醸造元株式会社佐浦': '宮城県',
#  '阿部勘酒造株式会社': '宮城県',
#  '墨廼江酒造': '宮城県',
#  '平孝酒造': '宮城県',
#  '藤井酒造株式会社': '広島県',
#  '中尾醸造株式会社': '広島県',
#  '株式会社一ノ蔵': '宮城県',
#  '白蘭酒造株式会社': '広島県',
#  '株式会社今田酒造本店': '広島県',
#  '柄酒造株式会社': '広島県',
#  '盛川酒造株式会社': '広島県',
#  '門傳醸造株式会社': '宮城県',
#  '株式会社角星': '宮城県',
#  '山岡酒造株式会社': '広島県',
#  '男山本店': '宮城県',
#  '蔵王酒造株式会社': '宮城県',
#  '大沼酒造店': '宮城県',
#  '株式会社小野酒造店': '宮城県',
#  '川敬商店': '宮城県',
#  '石越醸造株式会社': '宮城県',
#  '生熊酒造株式会社': '広島県',
#  '美和桜酒造有限会社': '広島県',
#  '株式会社浅勘酒造店': '宮城県',
#  '富久錦株式会社': '兵庫県',
#  '神結酒造株式会社': '兵庫県',
#  '神崎酒造有限会社': '兵庫県',
#  '名城酒造株式会社': '兵庫県',
#  'ヤヱガキ酒造株式会社': '兵庫県',
#  '寿酒造株式会社': '大阪府',
#  '聖酒造株式会社': '群馬県',
#  '清鶴酒造株式会社': '大阪府',
#  '大門酒造株式会社': '大阪府',
#  '山野酒造株式会社': '大阪府',
#  '藤本雅一酒造醸': '大阪府',
#  '西條合資会社': '大阪府',
#  '堺泉酒造有限会社': '大阪府',
#  '有限会社北庄司酒造店': '大阪府',
#  '浪花酒造有限会社': '大阪府',
#  '宝酒造株式会社': '京都府',
#  '羽田酒造有限会社': '京都府',
#  '佐々木酒造株式会社': '京都府',
#  '松井酒造株式会社': '京都府',
#  '城陽酒造株式会社': '京都府',
#  '東山酒造有限会社': '京都府',
#  '藤岡酒造株式会社': '京都府',
#  '都鶴酒造株式会社': '京都府',
#  '玉乃光酒造株式会社': '京都府',
#  '松本酒造株式会社': '京都府',
#  '齊藤酒造株式会社': '京都府',
#  '黄桜株式会社': '京都府',
#  '株式会社豊澤本店': '京都府',
#  '招德酒造株式会社': '京都府',
#  '株式会社京姫酒造': '京都府',
#  '株式会社北川本家': '京都府',
#  '月桂冠株式会社': '京都府',
#  'キンシ正宗株式会社': '京都府',
#  '東和酒造有限会社': '京都府',
#  '株式会社増田徳兵衛商店': '京都府',
#  '大石酒造株式会社': '京都府',
#  '丹山酒造有限会社': '京都府',
#  '若宮酒造株式会社': '京都府',
#  '池田酒造株式会社': '京都府',
#  'ハクレイ酒造株式会社': '京都府',
#  '吉岡酒造場': '京都府',
#  '竹野酒造有限会社': '京都府',
#  '株式会社文太郎': '兵庫県',
#  '有限会社長老': '京都府',
#  '白糸酒造株式会社': '京都府',
#  '与謝娘酒造合名会社': '京都府',
#  '谷口酒造株式会社': '京都府',
#  '白杉酒造株式会社': '京都府',
#  '熊野酒造有限会社': '京都府',
#  '木下酒造有限会社': '京都府',
#  '浪乃音酒造株式会社': '滋賀県',
#  '株式会社福井弥平商店': '滋賀県',
#  '川島酒造株式会社': '滋賀県',
#  '上原酒造株式会社': '滋賀県',
#  '池本酒造有限会社': '滋賀県',
#  '吉田酒造有限会社': '滋賀県',
#  '松瀬酒造株式会社': '滋賀県',
#  '竹内酒造株式会社': '滋賀県',
#  '北島酒造株式会社': '滋賀県',
#  '瀬古酒造株式会社': '滋賀県',
#  '望月酒造株式会社': '滋賀県',
#  '多賀株式会社': '滋賀県',
#  '太田酒造株式会社': '滋賀県',
#  '近江酒造株式会社': '滋賀県',
#  '美冨久酒造株式会社': '滋賀県',
#  '笑四季酒造株式会社': '滋賀県',
#  '滋賀酒造株式会社': '滋賀県',
#  '藤本酒造株式会社': '滋賀県',
#  '安井酒造場': '滋賀県',
#  '山路酒造有限会社': '滋賀県',
#  '株式会社岡村本家': '滋賀県',
#  '愛知酒造有限会社': '滋賀県',
#  '藤居本家': '滋賀県',
#  '矢尾酒造株式会社': '滋賀県',
#  '株式会社宮﨑本店': '三重県',
#  '清水清三郎商店株式会社': '三重県',
#  '株式会社小川本家': '三重県',
#  '神楽酒造株式会社': '三重県',
#  '有限会社稲垣酒造場': '三重県',
#  '合資会社早川酒造部': '三重県',
#  '細川酒造株式会社': '三重県',
#  '合資会社後藤酒造場': '三重県',
#  '丸彦酒造株式会社': '三重県',
#  '伊藤酒造株式会社': '三重県',
#  '石川酒造株式会社': '三重県',
#  '株式会社油正': '三重県',
#  '中山酒造株式会社': '三重県',
#  '株式会社伊勢萬': '三重県',
#  '合名会社森喜酒造場': '三重県',
#  '株式会社大田酒造': '三重県',
#  '若戎酒造株式会社': '三重県',
#  '澤佐酒造合名会社': '三重県',
#  '瀧自慢酒造株式会社': '三重県',
#  '合名会社森本仙右衛門商店': '三重県',
#  '橋本酒造場': '三重県',
#  '河武醸造株式会社': '三重県',
#  '元坂酒造株式会社': '三重県',
#  '合名会社伊勢屋商店': '愛知県',
#  '関谷醸造株式会社': '愛知県',
#  '福井酒造株式会社': '愛知県',
#  '丸石醸造株式会社': '愛知県'}

# %%
# version 2
pref_mapping = dict(df_pref[['Prefecture.1', 'Prefecture']].values)
pref_mapping
# Out:
# {'愛知県': 'Aichi',
#  '秋田県': 'Akita',
#  '青森県': 'Aomori',
#  '千葉県': 'Chiba',
#  '愛媛県': 'Ehime',
#  '福井県': 'Fukui',
#  '福岡県': 'Fukuoka',
#  '福島県': 'Fukushima',
#  '岐阜県': 'Gifu',
#  '群馬県': 'Gunma',
#  '広島県': 'Hiroshima',
#  '北海道': 'Hokkaido',
#  '兵庫県': 'Hyōgo',
#  '茨城県': 'Ibaraki',
#  '石川県': 'Ishikawa',
#  '岩手県': 'Iwate',
#  '香川県': 'Kagawa',
#  '鹿児島県': 'Kagoshima',
#  '神奈川県': 'Kanagawa',
#  '高知県': 'Kōchi',
#  '熊本県': 'Kumamoto',
#  '京都府': 'Kyoto',
#  '三重県': 'Mie',
#  '宮城県': 'Miyagi',
#  '宮崎県': 'Miyazaki',
#  '長野県': 'Nagano',
#  '長崎県': 'Nagasaki',
#  '奈良県': 'Nara',
#  '新潟県': 'Niigata',
#  '大分県': 'Ōita',
#  '岡山県': 'Okayama',
#  '沖縄県': 'Okinawa',
#  '大阪府': 'Osaka',
#  '佐賀県': 'Saga',
#  '埼玉県': 'Saitama',
#  '滋賀県': 'Shiga',
#  '島根県': 'Shimane',
#  '静岡県': 'Shizuoka',
#  '栃木県': 'Tochigi',
#  '徳島県': 'Tokushima',
#  '東京都': 'Tokyo',
#  '鳥取県': 'Tottori',
#  '富山県': 'Toyama',
#  '和歌山県': 'Wakayama',
#  '山形県': 'Yamagata',
#  '山口県': 'Yamaguchi',
#  '山梨県': 'Yamanashi'}

# %%
# create a dictionary with multiple 
dict_company_info = pd.Series(list(df_sake[['prefecture', 'city', 'address', 'website']].values), index=df_sake.company).to_dict()
